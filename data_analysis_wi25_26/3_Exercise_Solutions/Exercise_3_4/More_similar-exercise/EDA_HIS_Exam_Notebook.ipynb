# %% [markdown]
# # Advanced EDA — High-Integrity Systems Exam
# This notebook contains exam questions.

# %% [markdown]
# ## Section A — MCQs
# 1. Which variable is categorical?
# 2. Best plot for clusters?
# 3. Right-skewed implication?
# ...

# %% [markdown]
# 1. Which variable is categorical in this dataset?
# A. memory_usage_mb
# B. mode
# C. sensor_latency_ms
# D. uptime_hours

# %% [markdown]
# 2. The best plot for identifying clusters between CPU and memory usage is:
# A. Histogram
# B. Boxplot
# C. Scatter plot
# D. Count plot
# ________________________________________
# 3. A right-skewed distribution of uptime_hours implies:
# A. Most systems fail early
# B. Most systems run for short periods; few run extremely long
# C. System modes are equally distributed
# D. Data contains no anomalies
# ________________________________________
# 4. The measure least affected by extreme outliers is:
# A. Mean
# B. Median
# C. Standard deviation
# D. Range
# ________________________________________
# 5. High kurtosis in sensor_latency_ms indicates:
# A. A flat distribution with few extremes
# B. A normal distribution
# C. Frequent extreme latencies
# D. No variability
# ________________________________________
# 6. Which two variables are most likely to be correlated?
# A. CPU_temperature and cpu_usage_percent
# B. sensor_latency_ms and mode
# C. error_count and CPU_thermostat_stability
# D. memory_usage_mb and temperature_sensor
# ________________________________________
# 7. To detect outliers using IQR, you need:
# A. Min and Max
# B. Q1, Q3, IQR
# C. Mean and variance
# D. Mode only
# ________________________________________
# 8. A boxplot is NOT ideal when the distribution is:
# A. Normal
# B. Multimodal
# C. Right-skewed
# D. Symmetric
# ________________________________________
# 9. The coefficient of variation (CV) is useful when:
# A. Comparing variables with different units
# B. Data is categorical
# C. Data has no missing values
# D. There are no outliers
# ________________________________________
# 10. A heatmap of correlations helps identify:
# A. Outliers
# B. Data types
# C. Linear relationships
# D. Skewness

# %% [markdown]
# ## Section B — Short Answer
#
# 11. Explain why mode (normal, emergency, etc.) must be treated as a categorical variable.
# → Reference: measurement levels, non-numeric semantics.
# ________________________________________
# 12. Why can using standard deviation alone to compare CPU_thermostat_stability and sensor_thermostat_stability be misleading?
# ________________________________________
# 13. Describe the shape of a distribution where: mean > median > mode. What does this imply about system behavior?
# ________________________________________
# 14. Give one real-world reason why uptime_hours may contain many legitimate outliers.
# ________________________________________
# 15. When would a histogram be more appropriate than a bar plot? Explain with an example from this dataset.

# %% [markdown]
# ## Section C — Coding
# 16. Compute Q1,Q3,IQR for sensor_latency_ms.
# ...
# ```python
# # your code here
# ```

# %%
# 16. Write Python code to compute Q1, Q3, and IQR for sensor_latency_ms.

# %%
# 17. Write a command to calculate the coefficient of variation (CV) of CPU_temperature.

# %%
# 18. Using pandas, write code to detect outliers in uptime_hours using the IQR method.

# %% [markdown]
# ## Section D — Interpretation
# 21. Interpret memory_usage_mb outliers.
# ...

# %% [markdown]
# ## Section E — Applied Analysis
# 25. Hazardous mode detection.
# ...
