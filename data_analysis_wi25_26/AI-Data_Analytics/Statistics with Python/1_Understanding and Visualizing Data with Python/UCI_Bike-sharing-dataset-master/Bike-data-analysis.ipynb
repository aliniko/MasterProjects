# %%
# # Importing Libraries and loading Data using Pandas Library


import pandas as pd
import numpy as np
import seaborn as sns;sns.set()
import matplotlib.pyplot as plt

plt.style.use("ggplot")
sns.set(style="ticks")

# %%
data = pd.read_csv("D:/Master_exercises/IDA/AI-Data_Analytics/Statistics with Python/1_Understanding and Visualizing Data with Python/UCI_Bike-sharing-dataset-master/hour.csv")

# %%
#importing data using pandas library
data['formatted_date'] = pd.to_datetime(data['dteday'])

# data['Week_Number'] = pd.to_datetime(data['dteday']).dt.week

# %%
#Taking out Data info and printing first Few cells of the data
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1
#
#   formatted_date
# 0     2011-01-01
# 1     2011-01-01
# 2     2011-01-01
# 3     2011-01-01
# ...

# %%
# # Creating a Auto - Correlation matrix heatmap for the Data Set

#data = data.drop(['formatted_date',"dteday"],1)
data1 = data-data.mean()
data2 = data1.T@data1
data2 = data2/17379

sd = data.std()
sd1 = np.multiply.outer(sd.to_numpy(),sd.to_numpy())

final = data2/sd1
f, ax = plt.subplots(figsize=(20,15))
ax = sns.heatmap(final,vmin=-0.25, vmax=1,annot=True, fmt="f",linewidths=.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # # Creating a Auto - Correlation matrix heatmap for the Data Set
#       2
#       3 #data = data.drop(['formatted_date',"dteday"],1)
# ----> 4 data1 = data-data.mean()
#       5 data2 = data1.T@data1
#       6 data2 = data2/17379
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)  11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
# ...
